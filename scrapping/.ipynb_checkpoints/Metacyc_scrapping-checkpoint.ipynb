# %%
from bs4 import BeautifulSoup
import requests
import pickle

# %%
page = requests.get("https://biocyc.org/META/NEW-IMAGE?type=PATHWAY&object=PWY-8044")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#  <head>
#   <title>
#    MetaCyc cyclohexane-1-carboxyl-CoA biosynthesis
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script src="https://code.jquery.com/jquery-1.11.3.min.js">
#   </script>
#   <!-- <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script-->
#   <script>
#    var $j = jQuery.noConflict();
#   </script>
#   <!--
# <link rel="stylesheet" type="text/css" href="/yui/build/assets/skins/sam/skin.css">
# <link rel="stylesheet" type="text/css" href="/yui/build/assets/skins/sam/treeview.css">
# <link rel="stylesheet" type="text/css" href="/style.css" >
#
# User web site style sheet customization should use the following file:
# <link rel="stylesheet" type="text/css" href="/userWebsiteCustomization.css">
#
# The previous 4 .css files are combined at web start up time by the Lisp fn publish-combined-static-files generating the following combined.css file. For some
# reason it doesn't work for the yui gallery file to be combined -- the yui loader
# still looks for it as a separate file.
# -->
#   <link href="/yui3/build/gallery-datatable-selection/assets/skins/sam/gallery-datatable-selection.css" rel="stylesheet" type="text/css"/>
#   <link href="/combined/combined.css" rel="stylesheet" type="text/css"/>
#   <link href="//cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <!-- this has to go early -->
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/yui/3.17.2/yui/yui-min.js" type="text/javascript">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/prototype/1.7.3.0/prototype.js">
#   </script>
#   <script src="/combined/combined-early.js" type="text/javascript">
#   </script>
#   <!-- paley:Jun-15-2017 Comment these out, let them be autoloaded from the cdn:
# <script type="text/javascript" src="/yui3/build/yui-base/yui-base-min.js"></script>
# <script type="text/javascript" src="/yui3/build/base-build/base-build-min.js"></script>
# <script type="text/javascript" src="/yui3/build/datatable-base/datatable-base-min.js"></script>
# <script type="text/javascript" src="/yui3/build/event-custom-base/event-custom-base-min.js"></script>
#
# These 2 files are not in the cloudflare cdn, so we need to load them from our own site.  They're in the combined-early file
# <script type="text/javascript" src="/yui3/build/gallery-datatable-selection/gallery-datatable-selection.js"></script>
# <script type="text/javascript" src="/yui3/build/gallery-timer/gallery-timer-min.js"></script>
#
# These are bundled into the combined-early.js file:
# <script type="text/javascript" src="/yui/build/utilities/utilities.js"></script>
#    LOADED SEPARATELY (see above) <script TYPE="text/javascript" SRC="/wupub/prototype.js"></script>
# <script TYPE="text/javascript" SRC="/image-map-resizer-master/js/imageMapResizer.min.js"></script>
# -->
#   <!-- next 3 css for webgraphics -->
#   <link href="/yui/build/fonts/fonts-min.css" rel="stylesheet" type="text/css">
#    <!-- paley:Sep-10-2018 These are not found, and don't seem to be necessary.
# <link rel="stylesheet" type="text/css" href="/yui/build/button/assets/skins/sam/button.css" />
# <link rel="stylesheet" type="text/css" href="/yui/build/container/assets/skins/sam/container.css" />
# -->
#    <script src="/webgraphics.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     var onMenuBarReady = new YAHOO.util.CustomEvent("onMenuBarReady");
# /* This event fires when we change the current organism using the organism
#  * selector, so that subscribers can update the page accordingly.
#  */
# var organismChangedEvent = new YAHOO.util.CustomEvent("organismChanged");
#
# /* If you update the version number here, make sure you also update it in
#    pathwayTools.js (and the minified file)!!!
#  */
# YAHOO.util.Event.onContentReady("body", function() {
#   if (typeof(ptoolsJsVersion) == 'undefined' || ptoolsJsVersion !== '24.0') {
#       console.log('reloading because of outdated javascript file');
#       window.location.reload(true);
#       }
#   });
#    </script>
#    <!-- Base Pathway Tools JavaScript code -->
#    <script src="/pathwayTools-min.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     var typeObjectPage = {object:'PWY-8044',orgid:'META',type:'Pathways',biopax2:true,biopax3:true,tf:false,gene:false}
#    </script>
#    <!-- billingt:Jul-5-2014 START pathway-overviews-template.shtml Ripped out of celOv.shtml -->
#    <!-- for google-charts very directly -->
#    <script src="https://www.gstatic.com/charts/loader.js">
#    </script>
#    <!-- Rolled into combined-pwy-popups.css
#   <link rel="stylesheet" href="/overviewsWeb/theme/default/style.css" type="text/css"/>
#   <link type="text/css" rel="stylesheet" href="/yui/build/datatable/assets/datatable.css">
#   <link rel="stylesheet" type="text/css" href="/yui/build/fonts/fonts-min.css" />
#  -->
#    <link href="/combined/combined-pwy-popups.css" rel="stylesheet" type="text/css">
#     <!-- Rolled into combined-pwy-popups.js
#   <script type="text/javascript" src="/yui/build/json/json-min.js"></script>
#   <script type="text/javascript" src="/yui/build/swf/swf-min.js"></script>
#   <script type="text/javascript" src="/yui/build/charts/charts-min.js"></script>
#   <script type="text/javascript" src="/yui/build/datatable/datatable-min.js"></script>
#   <script type="text/javascript" src="/overviewsWeb/pathwayTools-overviews.js"></script>
#   <script type="text/javascript" src="/pathwayPopups.js"></script>
#   -->
#     <script src="/combined/combined-pwy-popups.js" type="text/javascript">
#     </script>
#     <!-- billingt:Oct-10-2013
#      style added for layer switcher "list" button display
# -->
#     <style type="text/css">
#      .olControlLayerSwitcher .layersDiv .baseLayersDiv,
#   .olControlLayerSwitcher .layersDiv .dataLayersDiv {
#     padding-left: 10px;
#     display: inline;
# }
#     </style>
#     <style type="text/css">
#      .yui-skin-sam .yui-panel .hd {
#   padding-top: 2px;
#   padding-right: 15px;
#   padding-bottom: 2px;
#   padding-left: 10px;
#   white-space: normal;
#   line-height: 1.05;
#   <!-- height: 20px; -->
# }
#     </style>
#     <style type="text/css">
#      .yui-skin-sam .container-close {
#   position: absolute;
#   top: 1px;
#   right: 2px;
#   width: 16px;
#   height: 13px;
#   background: url(/x.gif) no-repeat;
#   cursor: pointer;
#   }
#
#   .yui-skin-sam .yui-dt table {
#   padding-top: 0px;
#   padding-right: 3px;
#   padding-bottom: 0px;
#   padding-left: 3px;
#   }
#
#   .yui-skin-sam .yui-dialog .ft {
#   padding-top: 0px;
#   padding-right: 0px;
#   padding-bottom: 0px;
#   padding-left: 0px;
#   }
#
#   .yui-skin-sam .yui-resize .yui-resize-handle .yui-resize-handle-inner-r {
#   height:  0%;
#   width:  0%;
#   }
#
#   .yui-skin-sam .yui-resize .yui-resize-handle-r {
#   height:  0%;
#   width:  0%;
#   }
#
#   .yui-skin-sam .yui-resize .yui-resize-handle-b {
#   height:  0%;
#   width:  0%;
#   }
#
#
#   .yui-skin-sam .yui-resize .yui-resize-handle .yui-resize-handle-inner-b {
#   height:  0%;
#   width:  0%;
#   }
#
#   .yui-skin-sam .yui-resize .yui-resize-handle-br {
#   height:  0%;
#   width:  0%;
#   }
#     </style>
#     <!-- billingt:Jul-5-2014 END pathway-overviews-template.shtml -->
#     <!--  Text, Cite includes from Preferences -->
#     <style type="text/css">
#      @import url(/looks/cite-mnemonic.css);
#     </style>
#     <!-- End Text, Cite includes from Preferences -->
#    </link>
#   </link>
#  </head>
#  <body class="yui-skin-sam yui3-skin-sam" id="body" onload="initOnWindowLoad()">
#   <!--next line is used for determining text size for sizing window, tooltips, buttons, etc billingt:Jul-7-2014 -->
#   <!-- display: none is necessary or space will be left on the screen for this invisible area -->
#   <span id="textSizeTestArea" style="visibility: hidden; display: none">
#   </span>
#   <!--Fixed Navigation Box-->
#   <div class="navBox" id="navBox" style="display:none">
#    <div class="navBoxExpansion" id="navBoxExpanded">
#     <a href="#" onclick="hideNavBox()">
#      <img height="9" src="/navbox-hide.png" width="9"/>
#      hide
#     </a>
#    </div>
#    <div class="navBoxExpansion" id="navBoxCollapsed" style="display:none">
#     <a href="#" onclick="showNavBox()">
#      <img height="9" src="/navbox-show.png" width="9"/>
#      show operations
#     </a>
#    </div>
#    <div id="navBoxBody">
#     <br/>
#     <div id="navBoxTitle">
#      <div class="navBoxItem">
#       <i>
#        <a class="dynDBName" href="organism-summary">
#        </a>
#       </i>
#      </div>
#      <div class="navBoxLabel" id="objtypeNavBox">
#      </div>
#      <div class="navBoxItem" id="objnameNavBox">
#      </div>
#     </div>
#     <span class="section1">
#      OPERATIONS
#     </span>
#     <div id="navBoxOps">
#     </div>
#    </div>
#   </div>
#   <!--End Fixed Navigation Box-->
#   <!-- The top banner, we are in a body -->
#   <!-- We need this div to have position:relative in order for the z-index of the menu stacking to work -->
#   <div id="topBannerMenu">
#    <table border="0" cellpadding="0" style="border-collapse:collapse" width="100%">
#     <tr>
#      <td>
#       <div id="ptbanner">
#        <a class="logo" href="/" id="logoLink">
#        </a>
#        <!-- Begininng temporary message.
#      See file temporary-message-help.txt in this directory
#      for instructions on how to insert a temporary message -->
#        <!-- The set of BioCyc temporary messages must all be inside the following div  -->
#        <div id="biocycTmpMessages">
#        </div>
#        <!-- The set of EcoCyc temporary messages must all be inside the following div -->
#        <div id="ecocycTmpMessages">
#        </div>
#        <!-- The set of MetaCyc temporary messages must all be inside the following div -->
#        <div id="metacycTmpMessages">
#        </div>
#        <!-- The set of HumanCyc temporary messages must all be inside the following div -->
#        <div id="humancycTmpMessages">
#        </div>
#        <!-- The set of BsubCyc temporary messages must all be inside the following div -->
#        <div id="bsubcycTmpMessages">
#        </div>
#        <script>
#         YAHOO.util.Event.onContentReady("body", function() {
#   if (typeof(defaultTypeObjectPage) == 'undefined') {
#       console.log('reloading');
#       window.location.reload(true);
#       }
#       });
#        </script>
#        <!-- Login line and overlays for login help, etc. is in the following file -->
#        <!-- requires prototype, now included in template-standard-head-content -->
#        <div id="ilogin">
#        </div>
#        <script type="text/javascript">
#         new Ajax.Updater('ilogin', '/login-area');
#        </script>
#        <div class="searchGroupingExternalBox">
#         <div class="searchGroupingInternalBox">
#          <!-- Quick Search -->
#          <form action="/" class="searchMenu" name="substring" onsubmit="if (this.elements[1].value != '') {this.action= '/'+orgID()+'/substring-search?type=NIL&amp;object='+this.elements[1].value} else return(false);">
#           <input id="QSType" name="type" type="hidden" value="NIL"/>
#           <input class="inputQuickSearch" id="QSTextBox" name="object" placeholder="Enter a gene, protein, metabolite or pathway..." size="47" spellcheck="false" title="Enter one of the following (all searches conducted only within the selected organism, unless otherwise indicated):
#
# A name or synonym for a compound, gene, protein or pathway.  Spaces, punctuation and case are ignored. E.g. pyruvate, trpA
#
# Any substring of one of the above names, length &gt;= 3. E.g. kinase, pyr
#
# A full or partial EC number. E.g. 1.2.1.4, 1.3.1
#
# A full or partial InChI-key. E.g. CKLJMWTZIZZHCS
#
# An internal id (case-sensitive) for any compound, gene, protein, pathway, reaction or transcription-unit. E.g. CPLX0-3661, HEMN-RXN
#
# An id (case-sensitive) from another database to which this database contains links, e.g. UniProt, KEGG, ChEBI. Note that our set of links is not complete; even if an external id search returns no result the object may still be in our database. E.g. P00561, NP_414543, C00047
#
# A locus id for any gene of any organism on the BioCyc website. E.g. FTU_0031, YPA_0017
#
# (MetaCyc only) An organism or taxon name, to find pathways curated to that taxon. E.g. Bacillus, Shigella flexneri"/>
#           <input class="searchButton" name="quickSearch" type="submit" value="Quick Search"/>
#           <input class="searchButton" name="geneSearch" onclick="document.substring.type.value='GENE';" type="submit" value="Gene Search"/>
#          </form>
#          <!-- End Quick Search -->
#          <!-- Database name and change link -->
#          <div class="searchMenuDatabaseName">
#           Searching
#           <i>
#            <span class="dynDBName banner" id="currentDatabaseName">
#            </span>
#           </i>
#           <a href="javascript:void(0);" id="changeField" onclick="showChooser(false)" title="All searches will be conducted against the currently selected organism database.  To search a different organism, click this link and select a new database before submitting your query.">
#            change organism database
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- End Database name and change link -->
#       </div>
#      </td>
#     </tr>
#     <!-- The top menu bar -->
#     <tr>
#      <td>
#       <title>
#       </title>
#       <!-- The standard top menubar for Pathway Tools -->
#       <div class="yuimenubarnav" id="pathwayToolsMenubar" style="visibility:hidden">
#        <div class="bd">
#         <ul class="toolbar">
#          <li class="yuimenubaritem">
#           <a class="yuimenubaritemlabel" onclick="1">
#            Sites
#           </a>
#           <div class="yuimenu" id="home">
#            <div class="bd">
#             <ul class="first-of-type">
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="http://biocyc.org">
#                BioCyc
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="http://ecocyc.org">
#                EcoCyc
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="http://metacyc.org">
#                MetaCyc
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="http://humancyc.org">
#                HumanCyc
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="http://bsubcyc.org">
#                BsubCyc
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="http://bioinformatics.ai.sri.com/ptools/">
#                Pathway Tools
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#          <li class="yuimenubaritem">
#           <a class="yuimenubaritemlabel" onclick="1">
#            Search
#           </a>
#           <div class="yuimenu" id="search">
#            <div class="bd">
#             <ul class="first-of-type">
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/gene-search.shtml">
#                Search Genes, Proteins or RNAs
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/cpd-search.shtml">
#                Search Compounds
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/rxn-search.shtml">
#                Search Reactions
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/pwy-search.shtml">
#                Search Pathways
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/gm-search.shtml">
#                Search Growth Media
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/query.shtml">
#                Advanced Search
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li class="yuimenuitem" id="crossOrgSearch">
#               <a class="yuimenuitemlabel" href="/cross-org-search">
#                Cross Organism Search
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li class="yuimenuitem" id="blastMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/blast.html">
#                BLAST Search
#               </a>
#              </li>
#              <li class="yuimenuitem" id="blastAllMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/blast.html?refdb=ALL">
#                BLAST All BioCyc
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/full-text-search.shtml">
#                Google Search of this Site
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#          <li class="yuimenubaritem">
#           <a class="yuimenubaritemlabel" onclick="1">
#            Genome
#           </a>
#           <div class="yuimenu" id="genome">
#            <div class="bd">
#             <ul class="first-of-type">
#              <li class="yuimenuitem" id="genomeBrowserMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/select-gen-el">
#                Genome Browser
#               </a>
#              </li>
#              <li class="yuimenuitem" id="genOVMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/NEW-IMAGE?type=GENOME-OVERVIEW">
#                Genome Overview
#               </a>
#              </li>
#              <li class="yuimenuitem" id="regOVMenuItem">
#               <a class="yuimenuitemlabel" href="/overviewsWeb/regOv.shtml">
#                Regulatory Overview
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/class-tree?object=Gene-Ontology-Terms">
#                Browse Gene Ontology
#               </a>
#              </li>
#              <li class="yuimenuitem" id="mapSeqCoordMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/select-gen-el?type=MAP-SEQ-COORDS">
#                Map Sequence Coordinates
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#          <li class="yuimenubaritem">
#           <a class="yuimenubaritemlabel" onclick="1">
#            Metabolism
#           </a>
#           <div class="yuimenu" id="metabolism">
#            <div class="bd">
#             <ul class="first-of-type">
#              <li class="yuimenuitem" id="cellOVMenuItem">
#               <a class="yuimenuitemlabel" href="/overviewsWeb/celOv.shtml">
#                Cellular Overview
#               </a>
#              </li>
#              <li class="yuimenuitem" id="fbaMenu">
#               <a class="yuimenuitemlabel" href="/fba.shtml">
#                Run Metabolic Model
#               </a>
#              </li>
#              <li class="yuimenuitem" id="deadEndsMenuItem">
#               <a class="yuimenuitemlabel" href="/dead-end-form.shtml">
#                Dead-end Metabolites
#               </a>
#              </li>
#              <li class="yuimenuitem" id="chokepointsMenuItem">
#               <a class="yuimenuitemlabel" href="/chokepoint-form.shtml">
#                Chokepoint Reactions
#               </a>
#              </li>
#              <li class="yuimenuitem" id="metEngMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/meteng?organism=[ORGID]">
#                Metabolic Route Search
#               </a>
#              </li>
#              <li class="yuimenuitem" id="MetaboliteMenuItem">
#               <a class="yuimenuitemlabel" href="/metabolite-translation-service.shtml">
#                Metabolite Translation Service
#               </a>
#              </li>
#              <li class="yuimenuitem" id="pwyCollageMenuItem">
#               <a class="yuimenuitemlabel" href="/pathway-collage-info">
#                Pathway Collages
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/class-tree?object=Pathways">
#                Browse Pathway Ontology
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/class-tree?object=EC-Reactions">
#                Browse Enzyme Commission Ontology
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/class-tree?object=Compounds">
#                Browse Compound Ontology
#               </a>
#              </li>
#              <li class="yuimenuitem" id="cellOVPosterMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/poster-cellov?orgid=[ORGID]">
#                Generate Metabolic Map Poster
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#          <li class="yuimenubaritem">
#           <a class="yuimenubaritemlabel" onclick="1">
#            Analysis
#           </a>
#           <div class="yuimenu" id="analysis">
#            <div class="bd">
#             <ul class="first-of-type">
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/comp-genomics">
#                Comparative Analysis
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/PToolsWebsiteHowto.shtml#omicsDataAnalysis">
#                Omics Data Analysis
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/dashboard/dashboard-intro.shtml">
#                Omics Dashboard
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/organism-summary">
#                Summary Statistics
#               </a>
#              </li>
#              <li class="yuimenuitem" id="cmpdPwyCoverage">
#               <a class="yuimenuitemlabel" href="/cmpd-pwy-coverage.shtml">
#                Metabolomics Pathway Coverage
#               </a>
#              </li>
#              <li class="yuimenuitem" id="fungcMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/genome-context">
#                List Functional Gene Clusters
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/user-subscriptions.shtml">
#                Update Notifications
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a onclick="1">
#                Reports
#               </a>
#               <div class="yuimenu" id="reports">
#                <div class="bd">
#                 <ul class="first-of-type">
#                  <li class="yuimenuitem">
#                   <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/release-notes">
#                    History of updates
#                   </a>
#                  </li>
#                  <li class="yuimenuitem" id="pwyEvScoreMenuItem">
#                   <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/sort-by-score.html">
#                    Pathway evidence (sorted by score)
#                    <img src="/new.gif"/>
#                   </a>
#                  </li>
#                  <li class="yuimenuitem" id="pwyEvMenuItem">
#                   <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/hierarchical.html">
#                    Pathway evidence (sorted by class)
#                   </a>
#                  </li>
#                  <li class="yuimenuitem" id="pwyHolesMenuItem">
#                   <a class="yuimenuitemlabel orgspecific" href="/[ORGID]/missing-rxns.html">
#                    Pathway holes
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#          <li class="yuimenubaritem">
#           <a class="yuimenuibartemlabel" onclick="1">
#            SmartTables
#           </a>
#           <div class="yuimenu" id="groups">
#            <div class="bd">
#             <ul class="first-of-type">
#              <li class="yuimenuitem" id="groupsMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/groups?tab=PUBLIC&amp;orgid=[ORGID]">
#                Public SmartTables
#               </a>
#              </li>
#              <li class="yuimenuitem" id="groupsMenuItem">
#               <a class="yuimenuitemlabel orgspecific" href="/groups?tab=SPECIAL&amp;orgid=[ORGID]">
#                Special SmartTables
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#          <li class="yuimenubaritem">
#           <a class="yuimenubaritemlabel" onclick="1">
#            Help
#           </a>
#           <div class="yuimenu" id="help">
#            <div class="bd">
#             <ul class="first-of-type">
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/PToolsWebsiteHowto.shtml#SearchHelp">
#                Searching
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/PToolsWebsiteHowto.shtml">
#                Website User Guide
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/webinar.shtml">
#                Webinars
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/glossary.shtml">
#                Glossary
#               </a>
#              </li>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/PGDBConceptsGuide.shtml">
#                PGDB Concepts Guide
#               </a>
#              </li>
#              <li class="yuimenuitem" id="BioCycGuide">
#               <a class="yuimenuitemlabel" href="/BioCycUserGuide.shtml">
#                Guide to BioCyc
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li class="yuimenuitem">
#               <a class="yuimenuitemlabel" href="/contact.shtml">
#                Contact Us/Licensing/Support
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <!-- end topBannerMenu -->
#   <!-- Begin template-require-login-overlay.shtml -->
#   <!-- Placeholder for popup messages -->
#   <div id="msgPopup">
#   </div>
#   <div class="pageContentDynamic">
#    <table class="spacingOnlyTable">
#     <tr>
#      <td style="text-align:left;vertical-align:top;padding-right:0">
#       <form action="/" class="ecobuttons" name="form2004861">
#        <input onclick="window.open('feedback.html?' + encodeURIComponent(location), 'bugreport', 'toolbar=no,dependent=yes,height=640,width=620,menubar=no,location=no,scrollbars=yes')" type="button" value="Provide Feedback"/>
#       </form>
#      </td>
#      <td style="text-align:left;vertical-align:top;padding-right:0">
#       <div id="mediaBox" style="margin:0px 0px 0px 7px">
#        <a href="javascript:void(0);" onclick="emailFriend();return false" title="share via email">
#         <img alt="" height="15" src="/mail2.png" style="background-color:orange;" width="15"/>
#        </a>
#        <a href="https://twitter.com/share" onclick="this.href+='?url='+location.href" target="_blank" title="share on twitter">
#         <img alt="twitter" height="15" src="/Twitter_logo_blue2.png" width="15"/>
#        </a>
#        <a href="http://www.facebook.com/sharer.php" target="_blank" title="share on facebook">
#         <img alt="" height="15" src="/f_logo1.png" width="15"/>
#        </a>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <script>
#    !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');
#   </script>
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.0&appId=638548716262275";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <script>
#    function emailFriend(){
#
#    var strrep ,ptitle = document.title;
#
# strrep= ptitle.replace(/"/g,'%22');
# strrep= ptitle.replace(/&/g,'%26');
#
# var mailtourl = "mailto:?subject=" +ptitle+ "&body=" +encodeURIComponent(location.href);
# location.href = mailtourl;
# return false
# }
#   </script>
#  </body>
# </html>
# <table width="100%">
#  <tr>
#   <td id="ltitle">
#   </td>
#   <td>
#    <script type="text/javascript">
#     <!--
# recordPageTitle('Pathway',"cyclohexane-1-carboxyl-CoA biosynthesis");
# //-->
#    </script>
#    <center>
#     <font class="header pageTitle">
#      <a class="ORGANISM-ORGKB" href="/META/organism-summary">
#       <i>
#        MetaCyc
#       </i>
#      </a>
#      Pathway: cyclohexane-1-carboxyl-CoA biosynthesis
#     </font>
#    </center>
#   </td>
#   <td align="right" valign="top">
#    <table>
#     <tr>
#      <td style="text-align:center;vertical-align:top">
#       <a class="EVIDENCE-GLYPH" href="javascript:void(0);" onclick="return overlib(SRC,'/META/reference.html?type=EVIDENCE-GLYPH&amp;object=(PWY-8044+%2210973220:EV-EXP-IDA:3757435037:caspi%22+%22Moore93a:EV-EXP-IDA:3757429972:caspi%22)', STICKY, WIDTH, 400, HEIGHT, 400, CAPTION, 'Evidence', LEFT, EXCLUSIVEOVERRIDE, EXCLUSIVE, CLOSECLICK);" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Evidence:&lt;/b&gt; Inferred from direct assay [Cropp00], Inferred from direct assay [Moore93a]&lt;br&gt;[Click for more details...]', WIDTH, 458);">
#        <img alt="Inferred from experiment" border="0" class="ev" src="/EV-EXP.gif"/>
#       </a>
#      </td>
#     </tr>
#    </table>
#   </td>
#   <td valign="top">
#   </td>
#  </tr>
# </table>
# <br/>
# <script type="text/javascript">
#  <!--
#  onMenuBarReady.subscribe(function() { addMenuOpToNavBox({"text":"Species Comparison","url":"\/compare-frame-in-orgs?type=PATHWAY&object=PWY-8044&initial-orgs=(META)","tooltip":"Navigate to a page with a table comparing this pathway (its enzymes, genes, operon organization) across selected organisms","menuId":"compareOps"}); });
# //-->
# </script>
# <form action="/" class="ecobuttons" name="form2004862">
#  Enzyme View:
#  <select onchange="location.href='/META/NEW-IMAGE?type=PATHWAY&amp;object=PWY-8044&amp;ENZORG='+this.options[this.selectedIndex].value">
#   <option selected="" value="NIL">
#    All Organisms
#   </option>
#   <option value="TAX-42684">
#    Streptomyces collinus
#   </option>
#   <option value="TAX-67297">
#    Streptomyces flaveolus
#   </option>
#   <option value="ALL">
#    All Enzymes
#   </option>
#   <option value="NONE">
#    No Enzymes
#   </option>
#  </select>
#  <select onchange="location.href='/META/NEW-IMAGE?type=PATHWAY&amp;object=PWY-8044&amp;EXP-ONLY='+this.options[this.selectedIndex].value">
#   <option value="T">
#    Hide Predicted Enzymes
#   </option>
#   <option selected="" value="NIL">
#    Show Predicted Enzymes
#   </option>
#  </select>
#  Detail Level:
#  <select onchange="location.href='/META/NEW-IMAGE?type=PATHWAY&amp;object=PWY-8044&amp;detail-level='+this.options[this.selectedIndex].value">
#   <option value="0">
#    Minimal Detail
#   </option>
#   <option value="1">
#    Main compounds only
#   </option>
#   <option selected="" value="2">
#    All compounds, enzymes
#   </option>
#   <option value="3">
#    Main compound structures
#   </option>
#   <option value="4">
#    All compound structures
#   </option>
#  </select>
# </form>
# <p class="ecoparagraph">
#  <div class="webGraphics" id="WG_PWY_8044_PWY_DIAGRAM_div" style="POSITION: RELATIVE; DISPLAY: BLOCK">
#   <script type="text/javascript">
#    WG.Load('/tmp/ptools-images/META/PWY-8044_PWY-DIAGRAM.wg', 'WG_PWY_8044_PWY_DIAGRAM_div');
#   </script>
#  </div>
# </p>
# <p class="ecoparagraph">
#  <span style="font-size:smaller">
#   This view shows enzymes only for those organisms listed below, in the list of taxa known to
#    possess the pathway.
#    If an enzyme name is shown in bold, there is experimental evidence for this enzymatic activity.
#  </span>
# </p>
# <p class="ecoparagraph">
#  Some taxa known to possess this pathway include
#  <a href="javascript:void(0);" onclick="return overlib(SRC,'/help.html?object=species-data-available', STICKY, WIDTH, 600, HEIGHT, 400, CAPTION, 'Help', CENTERPOPUP, EXCLUSIVEOVERRIDE, EXCLUSIVE, CLOSECLICK);" onmouseout="return nd();">
#   <i class="fa fa-question-circle green">
#   </i>
#  </a>
#  :
#  <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-42684" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Streptomyces collinus&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;42684&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;species&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group&lt;br&gt;  Actinobacteria &lt;actinobacteria&gt;&lt;br&gt;  Actinobacteria &lt;high GC Gram+&gt;&lt;br&gt;  Streptomycetales&lt;br&gt;  Streptomycetaceae&lt;br&gt;  Streptomyces', WIDTH, 500);">
#   Streptomyces collinus
#  </a>
#  ,
#  <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-67297" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Streptomyces flaveolus&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;67297&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;species&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group&lt;br&gt;  Actinobacteria &lt;actinobacteria&gt;&lt;br&gt;  Actinobacteria &lt;high GC Gram+&gt;&lt;br&gt;  Streptomycetales&lt;br&gt;  Streptomycetaceae&lt;br&gt;  Streptomyces', WIDTH, 500);">
#   Streptomyces flaveolus
#  </a>
#  ,
#  <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-1245512" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Streptomyces&lt;/i&gt; sp. &lt;i&gt;XZQH13&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;1245512&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;species&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group&lt;br&gt;  Actinobacteria &lt;actinobacteria&gt;&lt;br&gt;  Actinobacteria &lt;high GC Gram+&gt;&lt;br&gt;  Streptomycetales&lt;br&gt;  Streptomycetaceae&lt;br&gt;  Streptomyces&lt;br&gt;  unclassified Streptomyces', WIDTH, 500);">
#   Streptomyces sp. XZQH13
#  </a>
# </p>
# <p class="ecoparagraph">
#  Expected Taxonomic Range:
#  <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-201174" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Actinobacteria &lt;actinobacteria&gt;&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;201174&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;phylum&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group', WIDTH, 500);">
#   Actinobacteria &lt;actinobacteria&gt;
#  </a>
# </p>
# <p class="ecoparagraph">
#  Synonyms:
# cyclohexane-1-carboxylate biosynthesis
# </p>
# <p class="ecoparagraph">
#  <table>
#   <tr>
#    <td style="text-align:left;vertical-align:top">
#     Superclasses:
#    </td>
#    <td style="text-align:left;vertical-align:top">
#     <a class="ECOCYC-CLASS" href="/META/NEW-IMAGE?type=ECOCYC-CLASS&amp;object=Biosynthesis" onmouseout="return nd();" onmouseover="return overlib('This class contains pathways that constitute a cell\'s complete spectrum of biosynthetic capacities, including the routes of synthesis of small molecules, macromolecules and cell structure components.&lt;br&gt;When applicable, salvage pathways are included as well.  &lt;br&gt;', WIDTH, 500);">
#      Biosynthesis
#     </a>
#     →
#     <a class="ECOCYC-CLASS" href="/META/NEW-IMAGE?type=ECOCYC-CLASS&amp;object=Carbohydrates-Biosynthesis" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Pathway&lt;/b&gt;: Carbohydrate Biosynthesis&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: Carbohydrates-Biosynthesis', WIDTH, 415);">
#      Carbohydrate Biosynthesis
#     </a>
#    </td>
#   </tr>
#  </table>
# </p>
# <p class="ecoparagraph">
#  Summary:
#  <br/>
#  [
#  <a class="CITATION-REFERENCE" href="http://www.ncbi.nlm.nih.gov/pubmed/">
#   1
#  </a>
#  ]Some secondary metabolites that belong to the
#  <a class="COMPOUND" href="/META/NEW-IMAGE?type=COMPOUND&amp;object=Ansatrienins" onmouseout="return nd();" onmouseover="return overlib('The redox pair &lt;a href=&quot;/compound?orgid=META&amp;id=CPD-21971&quot;&gt;ansatrienin A&lt;/a&gt;/&lt;a href=&quot;/compound?orgid=META&amp;id=CPD-21972&quot;&gt;ansatrienin B&lt;/a&gt; were discovered in 1981 from &lt;a href=&quot;/META/NEW-IMAGE?object=TAX-68264&quot;&gt;&lt;i&gt;Streptomyces rishiriensis&lt;/i&gt;&lt;/a&gt; under the names mycotrienin I and mycotrienin II [&lt;a href=&quot;/META/reference.html?type=CITATION-REFERENCE&amp;object=%5bWeber81%5d&quot;&gt;Weber81&lt;/a&gt;]. The same compounds were reported one year later from &lt;a href=&quot;/META/NEW-IMAGE?object=TAX-42684&quot;&gt;&lt;i&gt;Streptomyces collinus&lt;/i&gt;&lt;/a&gt; under their currently used names [&lt;a href=&quot;http://www.ncbi.nlm.nih.gov/pubmed/7161186&quot;&gt;Sugita82a&lt;/a&gt;]. &lt;br&gt;&lt;br&gt;The unique structures of this family of compounds are characterized by three conjugated double bonds in the 21-membered macrolactam ring, and a cyclohexanoyl-alanyl side chain attached to the C-11 hydroxyl group of the ansa ring [&lt;a href=&quot;http://linkinghub.elsevier.com/retrieve/pii/S0040403900975312&quot;&gt;Damberg82&lt;/a&gt;]. They exhibit potent activity against fungi and yeasts, as well as cytotoxicity and limited antibacterial activity.', STICKY, NOCLOSE, WIDTH, 500);">
#   ansatrienins
#  </a>
#  family, such as
#  <a class="COMPOUND" href="/compound?orgid=META&amp;id=CPD-21971" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: ansatrienin A&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: CPD-21971&lt;br&gt;&lt;b&gt;Synonyms:&lt;/b&gt; mycotrienin I', WIDTH, 440);">
#   ansatrienin A
#  </a>
#  [
#  <a class="CITATION-REFERENCE" href="http://www.ncbi.nlm.nih.gov/pubmed/7161184" onmouseout="return nd();" onmouseover="return overlib(' Sugita M, Natori Y, Sasaki T, Furihata K, Shimazu A, Seto H, Otake N (1982). &lt;strong&gt;&quot;Studies on mycotrienin antibiotics, a novel class of ansamycins. I. Taxonomy, fermentation, isolation and properties of mycotrienins I and II.&quot;&lt;/strong&gt; J Antibiot (Tokyo) 35(11);1460-6. PMID: 7161184', WIDTH, 500);">
#   Sugita82
#  </a>
#  ] and
#  <a class="COMPOUND" href="/compound?orgid=META&amp;id=CPD-21973" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: trienomycin A&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: CPD-21973&lt;br&gt;&lt;b&gt;Synonyms:&lt;/b&gt; cyclohexane-1-carbonyl-D-alanyl-3-&lt;i&gt;O&lt;/i&gt;-methylprotoansatrienin', WIDTH, 500);">
#   trienomycin A
#  </a>
#  [
#  <a class="CITATION-REFERENCE" href="http://www.ncbi.nlm.nih.gov/pubmed/3840155" onmouseout="return nd();" onmouseover="return overlib(' Funayama S, Okada K, Komiyama K, Umezawa I (1985). &lt;strong&gt;&quot;Structure of trienomycin A, a novel cytocidal ansamycin antibiotic.&quot;&lt;/strong&gt; J Antibiot (Tokyo) 38(8);1107-9. PMID: 3840155', WIDTH, 500);">
#   Funayama85
#  </a>
#  ,
#  <a class="CITATION-REFERENCE" href="http://www.ncbi.nlm.nih.gov/pubmed/2991181" onmouseout="return nd();" onmouseover="return overlib(' Umezawa I, Funayama S, Okada K, Iwasaki K, Satoh J, Masuda K, Komiyama K (1985). &lt;strong&gt;&quot;Studies on a novel cytocidal antibiotic, trienomycin A. Taxonomy, fermentation, isolation, and physico-chemical and biological characteristics.&quot;&lt;/strong&gt; J Antibiot (Tokyo) 38(6);699-705. PMID: 2991181', WIDTH, 500);">
#   Umezawa85
#  </a>
#  ], contain a unique
#  <a class="COMPOUND" href="/compound?orgid=META&amp;id=CPD-575" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: cyclohexane-1-carboxylate&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: CPD-575', WIDTH, 337);">
#   cyclohexane-1-carboxylate
#  </a>
#  moiety linked via a D-alanine residue to the macrocyclic lactam ring. An unsubstituted cyclohexane ring at the terminus of a carbon chain is also found in
#  <a class="COMPOUND" href="/compound?orgid=META&amp;id=CPD-18764" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: asukamycin&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: CPD-18764', WIDTH, 277);">
#   asukamycin
#  </a>
#  [
#  <a class="CITATION-REFERENCE" href="http://pubs.acs.org/doi/abs/10.1021/ja00506a056" onmouseout="return nd();" onmouseover="return overlib(' Kakinuma K, Ikekawa N, Nakagawa A, Omura S (1979). &lt;strong&gt;&quot;The structure of asukamycin, a possible shunt metabolite from 3-dehydroquinic acid in the shikimate pathway.&quot;&lt;/strong&gt; Journal of the American Chemical Society 101(12);3402-3404.', WIDTH, 500);">
#   Kakinuma79
#  </a>
#  ] and
#  <a class="COMPOUND" href="/compound?orgid=META&amp;id=CPD-22120" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: phoslactomycin B&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: CPD-22120&lt;br&gt;&lt;b&gt;Synonyms:&lt;/b&gt; phospholine', WIDTH, 458);">
#   phoslactomycin B
#  </a>
#  [
#  <a class="CITATION-REFERENCE" href="http://www.ncbi.nlm.nih.gov/pubmed/2753809" onmouseout="return nd();" onmouseover="return overlib(' Fushimi S, Furihata K, Seto H (1989). &lt;strong&gt;&quot;Studies on new phosphate ester antifungal antibiotics phoslactomycins. II. Structure elucidation of phoslactomycins A to F.&quot;&lt;/strong&gt; J Antibiot (Tokyo) 42(7);1026-36. PMID: 2753809', WIDTH, 500);">
#   Fushimi89
#  </a>
#  ,
#  <a class="CITATION-REFERENCE" href="http://www.ncbi.nlm.nih.gov/pubmed/2793587" onmouseout="return nd();" onmouseover="return overlib(' Ozasa T, Tanaka K, Sasamata M, Kaniwa H, Shimizu M, Matsumoto H, Iwanami M (1989). &lt;strong&gt;&quot;Novel antitumor antibiotic phospholine. 2. Structure determination.&quot;&lt;/strong&gt; J Antibiot (Tokyo) 42(9);1339-43. PMID: 2793587', WIDTH, 500);">
#   Ozasa89
#  </a>
#  ]. All of these compounds are produced by
#  <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-1883" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Streptomyces&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;1883&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;genus&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group&lt;br&gt;  Actinobacteria &lt;actinobacteria&gt;&lt;br&gt;  Actinobacteria &lt;high GC Gram+&gt;&lt;br&gt;  Streptomycetales&lt;br&gt;  Streptomycetaceae', WIDTH, 500);">
#   <i>
#    Streptomyces
#   </i>
#  </a>
#  strains. In addition, unsubstituted cyclohexane ring has been shown to be biosynthesized and utilized as a starter unit for fatty acid biosynthesis in
#  <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-405212" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Alicyclobacillus acidocaldarius&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;405212&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;species&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group&lt;br&gt;  Firmicutes&lt;br&gt;  Bacilli&lt;br&gt;  Bacillales&lt;br&gt;  Alicyclobacillaceae&lt;br&gt;  Alicyclobacillus', WIDTH, 500);">
#   <i>
#    Alicyclobacillus acidocaldarius
#   </i>
#  </a>
#  and related bacteria
# [
#  <a class="CITATION-REFERENCE" href="http://pubs.acs.org/doi/abs/10.1021/ja00065a043" onmouseout="return nd();" onmouseover="return overlib(' Moore BS, Poralla K, Floss HG (1993). &lt;strong&gt;&quot;Biosynthesis of the cyclohexanecarboxylic acid starter unit of ω-cyclohexyl fatty acids in Alicyclobacillus acidocaldarius.&quot;&lt;/strong&gt; Journal of the American Chemical Society 115(12);5267-5274.', WIDTH, 500);">
#   Moore93
#  </a>
#  ].
#  <p class="ecocomment">
#   Studies with
#   <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-42684" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Streptomyces collinus&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;42684&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;species&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group&lt;br&gt;  Actinobacteria &lt;actinobacteria&gt;&lt;br&gt;  Actinobacteria &lt;high GC Gram+&gt;&lt;br&gt;  Streptomycetales&lt;br&gt;  Streptomycetaceae&lt;br&gt;  Streptomyces', WIDTH, 500);">
#    <i>
#     Streptomyces collinus
#    </i>
#   </a>
#   and
#   <a class="ORGANISM" href="/META/NEW-IMAGE?object=TAX-405212" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;&lt;i&gt;Alicyclobacillus acidocaldarius&lt;/i&gt;&lt;/b&gt;&lt;br&gt;NCBI Taxonomy ID: &lt;b&gt;405212&lt;/b&gt;&lt;br&gt;Rank: &lt;b&gt;species&lt;/b&gt;&lt;br&gt;Lineage:&lt;br&gt;  cellular organisms&lt;br&gt;  Bacteria &lt;bacteria&gt;&lt;br&gt;  Terrabacteria group&lt;br&gt;  Firmicutes&lt;br&gt;  Bacilli&lt;br&gt;  Bacillales&lt;br&gt;  Alicyclobacillaceae&lt;br&gt;  Alicyclobacillus', WIDTH, 500);">
#    <i>
#     Alicyclobacillus acidocaldarius
#    </i>
#   </a>
#   using labeled
#   <a class="COMPOUND" href="/compound?orgid=META&amp;id=SHIKIMATE" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: shikimate&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: SHIKIMATE&lt;br&gt;&lt;b&gt;Synonyms:&lt;/b&gt; shikimic acid, (3R,4S,5R)--3,4,5-trihydroxycyclohex-1-ene-1-carboxylate', WIDTH, 500);">
#    shikimate
#   </a>
#   have shown that the
#   <a class="COMPOUND" href="/compound?orgid=META&amp;id=CPD-575" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: cyclohexane-1-carboxylate&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: CPD-575', WIDTH, 337);">
#    cyclohexane-1-carboxylate
#   </a>
#   moiety is derived from
#   <a class="COMPOUND" href="/compound?orgid=META&amp;id=SHIKIMATE" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Compound&lt;/b&gt;: shikimate&lt;br&gt;&lt;b&gt;ID&lt;/b&gt;: SHIKIMATE&lt;br&gt;&lt;b&gt;Synonyms:&lt;/b&gt; shikimic acid, (3R,4S,5R)--3,4,5-trihydroxycyclohex-1-ene-1-carboxylate', WIDTH, 500);">
#    shikimate
#   </a>
#   in a pathway that involves a series of dehydration and double-bond reduction steps
# [
#   <a class="CITATION-REFERENCE" href="http://pubs.acs.org/doi/abs/10.1021/ja00260a035" onmouseout="return nd();" onmouseover="return overlib(' Casati R, Beale JM, Floss HG (1987). &lt;strong&gt;&quot;Biosynthesis of ansatrienin. Nonincorporation of shikimic acid into the mC&lt;sub&gt;7&lt;/sub&gt;N unit and stereochemistry of its conversion to the cyclohexanecarboxylic acid moiety.&quot;&lt;/strong&gt; Journal of the American Chemical Society 109(26);8102-8104.', WIDTH, 500);">
#    Casati87
#   </a>
#   ,
#   <a class="CITATION-REFERENCE" href="http://www.ncbi.nlm.nih.gov/pubmed/3598593" onmouseout="return nd();" onmouseover="return overlib(' Wu TS, Duncan J, Tsao SW, Chang CJ, Keller PJ, Floss HG (1987). &lt;strong&gt;&quot;Biosynthesis of the ansamycin antibiotic ansatrienin (mycotrienin) by Streptomyces collinus.&quot;&lt;/strong&gt; J Nat Prod 50(1);108-18. PMID: 3598593', WIDTH, 500);">
#    Wu87a
#   </a>
#   ,
#   <a class="CITATION-REFERENCE" href="http://pubs.acs.org/doi/abs/10.1021/ja00065a042" onmouseout="return nd();" onmouseover="return overlib(' Moore BS, Cho H, Casati R, Kennedy E, Reynolds KA, Mocek U, Beale JM, Floss HG (1993). &lt;strong&gt;&quot;Biosynthetic studies on ansatrienin A. Formation of the cyclohexanecarboxylic acid moiety.&quot;&lt;/strong&gt; Journal of the American Chemical Society 115(12);5254-5266.', WIDTH, 500);">
#    Moore93a
#   </a>
#   ,
# ...
#           <input id="mmdDelete3" onclick='mdRemoveClause(3, "m")' type="button" value="Remove Constraint"/>
#           <br/>
#           <table>
#            <tr>
#             <td>
#              <select id="mmdSlot3" onchange='updateMetadataSlot(3, "m")'>
#               <option selected="" value="false">
#                Select Property
#               </option>
#              </select>
#             </td>
#             <td>
#              <select id="mmdConstraint3" onchange='updateMetadataSlot(3, "m")'>
#               <option selected="" value="c">
#                has values
#               </option>
#               <option value="nc">
#                does not have values
#               </option>
#               <option value="a">
#                has any value
#               </option>
#               <option value="n">
#                has no value
#               </option>
#              </select>
#             </td>
#            </tr>
#           </table>
#           <table>
#            <tr>
#             <td>
#              <span id="mkeywordInput3" style="display:none">
#               <table>
#                <tr>
#                 <td>
#                  <select id="mmdKeywordOp3" onchange="updateForOp(3, 'mmdKeywordOp3', 'mmdSubstringAC3', 'm')">
#                   <option selected="" value="enum">
#                    Exact Match
#                   </option>
#                   <option value="substr">
#                    Substring Match
#                   </option>
#                  </select>
#                 </td>
#                 <td>
#                  <div class="mdSubstringInput" id="mmdSubstringAC3">
#                   <input id="mmdKeyword3" type="text"/>
#                   <div id="mmdKWContainer3">
#                   </div>
#                  </div>
#                 </td>
#                </tr>
#               </table>
#              </span>
#              <span id="mnumericInput3" style="display:none">
#               <table>
#                <tr>
#                 <td>
#                  <select id="mmdNumOp3" onchange="updateForOp(3, 'mmdNumOp3', 'mmdNum3', 'm')">
#                   <option selected="" value="e">
#                    = (approx.)
#                   </option>
#                   <option value="lt">
#                    &lt;
#                   </option>
#                   <option value="lte">
#                    ≤
#                   </option>
#                   <option value="gt">
#                    &gt;
#                   </option>
#                   <option value="gte">
#                    ≥
#                   </option>
#                   <option value="enum">
#                    Select Values
#                   </option>
#                  </select>
#                 </td>
#                 <td>
#                  <input id="mmdNum3" type="text"/>
#                 </td>
#                </tr>
#               </table>
#              </span>
#             </td>
#             <td id="mmdEnumContainer3" style="display:none">
#              <select id="mmdEnum3" multiple="">
#              </select>
#             </td>
#            </tr>
#           </table>
#          </div>
#          <div id="mclause4" style="display:none">
#           <select id="mconnector4">
#            <option selected="" value="and">
#             AND
#            </option>
#            <option value="or">
#             OR
#            </option>
#           </select>
#           <input id="mmdDelete4" onclick='mdRemoveClause(4, "m")' type="button" value="Remove Constraint"/>
#           <br/>
#           <table>
#            <tr>
#             <td>
#              <select id="mmdSlot4" onchange='updateMetadataSlot(4, "m")'>
#               <option selected="" value="false">
#                Select Property
#               </option>
#              </select>
#             </td>
#             <td>
#              <select id="mmdConstraint4" onchange='updateMetadataSlot(4, "m")'>
#               <option selected="" value="c">
#                has values
#               </option>
#               <option value="nc">
#                does not have values
#               </option>
#               <option value="a">
#                has any value
#               </option>
#               <option value="n">
#                has no value
#               </option>
#              </select>
#             </td>
#            </tr>
#           </table>
#           <table>
#            <tr>
#             <td>
#              <span id="mkeywordInput4" style="display:none">
#               <table>
#                <tr>
#                 <td>
#                  <select id="mmdKeywordOp4" onchange="updateForOp(4, 'mmdKeywordOp4', 'mmdSubstringAC4', 'm')">
#                   <option selected="" value="enum">
#                    Exact Match
#                   </option>
#                   <option value="substr">
#                    Substring Match
#                   </option>
#                  </select>
#                 </td>
#                 <td>
#                  <div class="mdSubstringInput" id="mmdSubstringAC4">
#                   <input id="mmdKeyword4" type="text"/>
#                   <div id="mmdKWContainer4">
#                   </div>
#                  </div>
#                 </td>
#                </tr>
#               </table>
#              </span>
#              <span id="mnumericInput4" style="display:none">
#               <table>
#                <tr>
#                 <td>
#                  <select id="mmdNumOp4" onchange="updateForOp(4, 'mmdNumOp4', 'mmdNum4', 'm')">
#                   <option selected="" value="e">
#                    = (approx.)
#                   </option>
#                   <option value="lt">
#                    &lt;
#                   </option>
#                   <option value="lte">
#                    ≤
#                   </option>
#                   <option value="gt">
#                    &gt;
#                   </option>
#                   <option value="gte">
#                    ≥
#                   </option>
#                   <option value="enum">
#                    Select Values
#                   </option>
#                  </select>
#                 </td>
#                 <td>
#                  <input id="mmdNum4" type="text"/>
#                 </td>
#                </tr>
#               </table>
#              </span>
#             </td>
#             <td id="mmdEnumContainer4" style="display:none">
#              <select id="mmdEnum4" multiple="">
#              </select>
#             </td>
#            </tr>
#           </table>
#          </div>
#          <div id="mclause5" style="display:none">
#           <select id="mconnector5">
#            <option selected="" value="and">
#             AND
#            </option>
#            <option value="or">
#             OR
#            </option>
#           </select>
#           <input id="mmdDelete5" onclick='mdRemoveClause(5, "m")' type="button" value="Remove Constraint"/>
#           <br/>
#           <table>
#            <tr>
#             <td>
#              <select id="mmdSlot5" onchange='updateMetadataSlot(5, "m")'>
#               <option selected="" value="false">
#                Select Property
#               </option>
#              </select>
#             </td>
#             <td>
#              <select id="mmdConstraint5" onchange='updateMetadataSlot(5, "m")'>
#               <option selected="" value="c">
#                has values
#               </option>
#               <option value="nc">
#                does not have values
#               </option>
#               <option value="a">
#                has any value
#               </option>
#               <option value="n">
#                has no value
#               </option>
#              </select>
#             </td>
#            </tr>
#           </table>
#           <table>
#            <tr>
#             <td>
#              <span id="mkeywordInput5" style="display:none">
#               <table>
#                <tr>
#                 <td>
#                  <select id="mmdKeywordOp5" onchange="updateForOp(5, 'mmdKeywordOp5', 'mmdSubstringAC5', 'm')">
#                   <option selected="" value="enum">
#                    Exact Match
#                   </option>
#                   <option value="substr">
#                    Substring Match
#                   </option>
#                  </select>
#                 </td>
#                 <td>
#                  <div class="mdSubstringInput" id="mmdSubstringAC5">
#                   <input id="mmdKeyword5" type="text"/>
#                   <div id="mmdKWContainer5">
#                   </div>
#                  </div>
#                 </td>
#                </tr>
#               </table>
#              </span>
#              <span id="mnumericInput5" style="display:none">
#               <table>
#                <tr>
#                 <td>
#                  <select id="mmdNumOp5" onchange="updateForOp(5, 'mmdNumOp5', 'mmdNum5', 'm')">
#                   <option selected="" value="e">
#                    = (approx.)
#                   </option>
#                   <option value="lt">
#                    &lt;
#                   </option>
#                   <option value="lte">
#                    ≤
#                   </option>
#                   <option value="gt">
#                    &gt;
#                   </option>
#                   <option value="gte">
#                    ≥
#                   </option>
#                   <option value="enum">
#                    Select Values
#                   </option>
#                  </select>
#                 </td>
#                 <td>
#                  <input id="mmdNum5" type="text"/>
#                 </td>
#                </tr>
#               </table>
#              </span>
#             </td>
#             <td id="mmdEnumContainer5" style="display:none">
#              <select id="mmdEnum5" multiple="">
#              </select>
#             </td>
#            </tr>
#           </table>
#          </div>
#          <br/>
#          <table>
#           <tr>
#            <td>
#             <input id="maddClause" onclick='mdAddClause("m")' style="display:none" type="button" value="Add Constraint"/>
#            </td>
#            <td>
#             <input id="mmdSearch" onclick='processMdQuery(true, "m")' type="button" value="Find Organisms"/>
#            </td>
#            <td style="vertical-align:middle;padding-left: 16px">
#             <div id="mmdProgress">
#             </div>
#            </td>
#           </tr>
#          </table>
#          <br/>
#          <div id="instructions" style="display:none">
#           Shift-click to select a range; Ctrl-click to select multiple non-contiguous organisms.
#          </div>
#          <div id="tableControls" style="display:none">
#           <input onclick="resultsTableSelectAll()" type="button" value="Select All"/>
#           <a download="" onclick='this.href=tableToDataURI("#mmdResults")'>
#            <input type="button" value="Download Results"/>
#           </a>
#          </div>
#          <div class="yui3-skin-sam" id="mmdResults">
#          </div>
#         </div>
#         <div class="multiorgselectorTab" id="multiorgSavedTab" style="overflow-y:auto">
#          <div style="padding-bottom:20px">
#           <span>
#            Database lists are saved as SmartTables that you can edit from your
#            <a href="/smarttables" target="new.window">
#             My SmartTables
#            </a>
#            page. To add organisms from a saved list, check the box next to the list name and then click the "Add" button.
#           </span>
#          </div>
#          <div class="ygtv-checkbox" id="multiorgSavedTree">
#          </div>
#          <div class="requiresNotLoggedIn" style="padding-top:50px">
#           Log in and reload this page to access your saved database lists.
#          </div>
#         </div>
#        </div>
#       </div>
#       <div id="tierKey">
#        <span class="tier1">
#         Tier 1
#        </span>
#        and
#        <span class="tier2">
#         Tier 2
#        </span>
#        databases are displayed with orange and gray backgrounds, respectively.
#       </div>
#      </td>
#      <td style="vertical-align:middle">
#       <table>
#        <tr id="multiorgSelectAllRow">
#         <td style="text-align:center">
#          <input class="disableWhenAllSelected" id="multiorgSelectAllBtn" onclick="multiorgSelectAll()" type="button" value="Select All"/>
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          <input class="disableWhenAllSelected" id="multiorgAddToList" onclick="addNewSelections()" type="button" value="Add →"/>
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          <input class="disableWhenAllSelected" id="multiorgDeleteFromList" onclick="deleteMultiorgOptions(false)" type="button" value="Remove ←"/>
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          <input id="multiorgClearAll" onclick="deleteMultiorgOptions(true)" type="button" value="Clear All"/>
#         </td>
#        </tr>
#       </table>
#      </td>
#      <td style="vertical-align:top">
#       <h3>
#        Current Selection
#       </h3>
#       <span id="multiNumSelected">
#        0
#       </span>
#       databases or taxa currently selected.
#       <p>
#        <div id="multiorgSelectionDiv">
#         <select id="multiorgSelection" multiple="">
#         </select>
#        </div>
#       </p>
#      </td>
#     </tr>
#    </table>
#    <p>
#     <div class="requiresNotLoggedIn" style="max-width:500px;padding-left:300px">
#      Note: if you create a user account and log in, you can save your database lists for next time.
#     </div>
#    </p>
#   </form>
#  </div>
# </div>
# <script type="text/javascript">
#  multiorg_maxOrgs = 70
# </script>
# <!-- End Multi Organism Chooser Template -->
# <script type="text/javascript">
#  if (forceOrgID) setOrganism(forceOrgID);
# </script>
# <script type="text/javascript">
#  function getparm(myparm)
#       //Returns a string which is the value contents of the &myparameter=value& in the URL.
#       {
#       var URL = location.href;
#       var result = URL.match("[?&]" + myparm + "=([^&]*)" );
#       return( result? result[1] : null ) ;
#       }
#
#       function setparm(myparm, newvalue)
#       //Returns a string which is the new URL with &myparameter=value& set properly in all cases.
#       {
#         var URL = location.href		;
#         var result			;
#         if( URL.search( "[?&]" + myparm + "=([^&]*)" ) > 5 )
#         {   //Parameter there already, replace it
#           var pattern = new RegExp("([?&])" + myparm + "=([^&]*)") ;
#           var replacement = "$1" + myparm + "=" + newvalue ;
#           result = URL.replace( pattern, replacement ) ;
#         }
#         else
#         {    //Parameter not there already.
#           if( URL.search( "[?]" ) > 5 )   //Do we have ANY parms yet?
#           {  //Yes.  Go ahead and simply tack it onto the end, with a &.
#             result = URL + "&" + myparm + "=" + newvalue ;
#           } else {  //New parameter.  Add it with a ? instead.
#             result = URL + "?" + myparm + "=" + newvalue ;
#           }
#         }
#         return(result)			;
#       }
#
#       function setparm3(myparm, newvalue, URL)
#       //Returns a string which is the new URL with &myparameter=value& set properly in all cases.
#       {
#         var result			;
#         if( URL.search( "[?&]" + myparm + "=([^&]*)" ) > 5 )
#         {   //Parameter there already, replace it
#           var pattern = new RegExp("([?&])" + myparm + "=([^&]*)") ;
#           var replacement = "$1" + myparm + "=" + newvalue ;
#           result = URL.replace( pattern, replacement ) ;
#         }
#         else
#         {    //Parameter not there already.
#           if( URL.search( "[?]" ) > 5 )   //Do we have ANY parms yet?
#           {  //Yes.  Go ahead and simply tack it onto the end, with a &.
#             result = URL + "&" + myparm + "=" + newvalue ;
#           } else {  //New parameter.  Add it with a ? instead.
#             result = URL + "?" + myparm + "=" + newvalue ;
#           }
#         }
#         return(result);
#       }
#
#      function substring_searchify_URL()
#      //Returns current URL with /substring-search?  added at end of address section if needed.
#      {
#          var URL = location.href;
#          if( URL.search( '\/substring-search\?' ) > 0 )
#              return( URL );
#          else
#              URL = URL.replace( /\/[^\/]*\?/, '/substring-search?');
#          //alert( URL );
#          return( URL );
#      }
# </script>

# %%
html = list(soup.children)[5]
print (html)
# Out:
# <table width="100%"><tr><td id="ltitle"></td><td>
# <script type="text/javascript">
# <!--
# recordPageTitle('Pathway',"cyclohexane-1-carboxyl-CoA biosynthesis");
# //-->
# </script>
# <center><font class="header pageTitle"><a class="ORGANISM-ORGKB" href="/organism-summary/META"><i>MetaCyc</i>
# </a> Pathway: cyclohexane-1-carboxyl-CoA biosynthesis</font></center>
# </td><td align="right" valign="top">
# <table><tr><td style="text-align:center;vertical-align:top"><a class="EVIDENCE-GLYPH" href="javascript:void(0);" onclick="return overlib(SRC,'/META/reference.html?type=EVIDENCE-GLYPH&amp;object=(PWY-8044+%2210973220:EV-EXP-IDA:3757435037:caspi%22+%22Moore93a:EV-EXP-IDA:3757429972:caspi%22)', STICKY, WIDTH, 400, HEIGHT, 400, CAPTION, 'Evidence', LEFT, EXCLUSIVEOVERRIDE, EXCLUSIVE, CLOSECLICK);" onmouseout="return nd();" onmouseover="return overlib('&lt;b&gt;Evidence:&lt;/b&gt; Inferred from direct assay [Cropp00], Inferred from direct assay [Moore93a]&lt;br&gt;[Click for more details...]', WIDTH, 458);"><img alt="Inferred from experiment" border="0" class="ev" src="/EV-EXP.gif"/></a></td></tr></table></td><td valign="top"></td></tr></table>

# %%
list(html.children)
body = list(html.children)[3]
print (body)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ad10eeae685a> in <module>
# ----> 1 list(html.children)
#       2 body = list(html.children)[3]
#       3 print (body)
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, attr)
#     883             raise AttributeError(
#     884                 "'%s' object has no attribute '%s'" % (
# --> 885                     self.__class__.__name__, attr))
#     886
#     887     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'children'

# %%
p = list(body.children)[1]
print (p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4787c177e580> in <module>
# ----> 1 p = list(body.children)[1]
#       2 print (p)
#
# NameError: name 'body' is not defined

# %%
soup.find_all('b')
# Out:
# [<b>KEGG PATHWAY</b>,
#  <b>1. Metabolism</b>,
#  <b>2. Genetic Information Processing</b>,
#  <b>3. Environmental Information Processing</b>,
#  <b>4. Cellular Processes</b>,
#  <b>5. Organismal Systems</b>,
#  <b>6. Human Diseases</b>,
#  <b>7. Drug Development</b>,
#  <b>KEGG Mapper</b>,
#  <b>1.0 Global and overview maps</b>,
#  <b>1.1 Carbohydrate metabolism</b>,
#  <b>1.2 Energy metabolism</b>,
#  <b>1.3 Lipid metabolism</b>,
#  <b>1.4 Nucleotide metabolism</b>,
#  <b>1.5 Amino acid metabolism</b>,
#  <b>1.6 Metabolism of other amino acids</b>,
#  <b>1.7 Glycan biosynthesis and metabolism</b>,
#  <b>1.8 Metabolism of cofactors and vitamins</b>,
#  <b>1.9 Metabolism of terpenoids and polyketides</b>,
#  <b>1.10 Biosynthesis of other secondary metabolites</b>,
#  <b>1.11 Xenobiotics biodegradation and metabolism</b>,
#  <b>1.12 Chemical structure transformation maps</b>,
#  <b>2.1 Transcription</b>,
#  <b>2.2 Translation</b>,
#  <b>2.3 Folding, sorting and degradation</b>,
#  <b>2.4 Replication and repair</b>,
#  <b>3.1 Membrane transport</b>,
#  <b>3.2 Signal transduction</b>,
#  <b>3.3 Signaling molecules and interaction</b>,
#  <b>4.1 Transport and catabolism</b>,
#  <b>4.2 Cell growth and death</b>,
#  <b>4.3 Cellular community - eukaryotes</b>,
#  <b>4.4 Cellular community - prokaryotes</b>,
#  <b>4.5 Cell motility</b>,
#  <b>5.1 Immune system</b>,
#  <b>5.2 Endocrine system</b>,
#  <b>5.3 Circulatory system</b>,
#  <b>5.4 Digestive system</b>,
#  <b>5.5 Excretory system</b>,
#  <b>5.6 Nervous system</b>,
#  <b>5.7 Sensory system</b>,
#  <b>5.8 Development and regeneration</b>,
#  <b>5.9 Aging</b>,
#  <b>5.10 Environmental adaptation</b>,
#  <b>6.1 Cancer: overview</b>,
#  <b>6.2 Cancer: specific types</b>,
#  <b>6.3 Immune disease</b>,
#  <b>6.4 Neurodegenerative disease</b>,
#  <b>6.5 Substance dependence</b>,
#  <b>6.6 Cardiovascular disease</b>,
#  <b>6.7 Endocrine and metabolic disease</b>,
#  <b>6.8 Infectious disease: bacterial</b>,
#  <b>6.9 Infectious disease: viral</b>,
#  <b>6.10 Infectious disease: parasitic</b>,
#  <b>6.11 Drug resistance: antimicrobial</b>,
#  <b>6.12 Drug resistance: antineoplastic</b>,
#  <b>7.1 Chronology: Antiinfectives</b>,
#  <b>7.2 Chronology: Antineoplastics</b>,
#  <b>7.3 Chronology: Nervous system agents</b>,
#  <b>7.4 Chronology: Other drugs</b>,
#  <b>7.5 Target-based classification: G protein-coupled receptors</b>,
#  <b>7.6 Target-based classification: Nuclear receptors</b>,
#  <b>7.7 Target-based classification: Ion channels</b>,
#  <b>7.8 Target-based classification: Transporters</b>,
#  <b>7.9 Target-based classification: Enzymes</b>,
#  <b>7.10 Structure-based classification</b>,
#  <b>7.11 Skeleton-based classification</b>]

# %%
extracted=soup.find_all(['dt','b'])
#print (extracted)
extracted_text=[i.get_text() for i in extracted]
#print (extracted_text)
starting_index=extracted_text.index('1.0 Global and overview maps')
interest_list=extracted_text[starting_index:]
#print (interest_list)
test=['1.1 Carbohydrate metabolism', '00010', '00020', '00030', '00040', '00051', '00052', 
      '00053', '00500', '00520', '00620', '00630', '00640', '00650', '00660', '00562', 
      '1.2 Energy metabolism', '00190', '00195', '00196', '00710', '00720', '00680', '00910', '00920']

# %%
label={};map_id={};map_name={}
for i,j in enumerate(interest_list):
    if '.' in j:
        name='-'.join(j.split()[1:])
        idd=j.split()[0]
        label[name]=[]
        for m,n in enumerate(interest_list[i+1:]):
            if '.' not in n:
                maps='map'+n
                label[name].append(maps)
                map_name[maps]=name
                map_id[maps]=idd
            else:
                break
            
print (label)
# Out:
# {'Global-and-overview-maps': ['map01100', 'map01110', 'map01120', 'map01200', 'map01210', 'map01212', 'map01230', 'map01220'], 'Carbohydrate-metabolism': ['map00010', 'map00020', 'map00030', 'map00040', 'map00051', 'map00052', 'map00053', 'map00500', 'map00520', 'map00620', 'map00630', 'map00640', 'map00650', 'map00660', 'map00562'], 'Energy-metabolism': ['map00190', 'map00195', 'map00196', 'map00710', 'map00720', 'map00680', 'map00910', 'map00920'], 'Lipid-metabolism': ['map00061', 'map00062', 'map00071', 'map00072', 'map00073', 'map00100', 'map00120', 'map00121', 'map00140', 'map00561', 'map00564', 'map00565', 'map00600', 'map00590', 'map00591', 'map00592', 'map01040'], 'Nucleotide-metabolism': ['map00230', 'map00240'], 'Amino-acid-metabolism': ['map00250', 'map00260', 'map00270', 'map00280', 'map00290', 'map00300', 'map00310', 'map00220', 'map00330', 'map00340', 'map00350', 'map00360', 'map00380', 'map00400'], 'Metabolism-of-other-amino-acids': ['map00410', 'map00430', 'map00440', 'map00450', 'map00460', 'map00471', 'map00472', 'map00473', 'map00480'], 'Glycan-biosynthesis-and-metabolism': ['map00510', 'map00513', 'map00512', 'map00515', 'map00514', 'map00532', 'map00534', 'map00533', 'map00531', 'map00563', 'map00601', 'map00603', 'map00604', 'map00540', 'map00550', 'map00511', 'map00571', 'map00572'], 'Metabolism-of-cofactors-and-vitamins': ['map00730', 'map00740', 'map00750', 'map00760', 'map00770', 'map00780', 'map00785', 'map00790', 'map00670', 'map00830', 'map00860', 'map00130'], 'Metabolism-of-terpenoids-and-polyketides': ['map00900', 'map00902', 'map00909', 'map00904', 'map00906', 'map00905', 'map00981', 'map00908', 'map00903', 'map00281', 'map01052', 'map00522', 'map01051', 'map01059', 'map01056', 'map01057', 'map00253', 'map00523', 'map01054', 'map01053', 'map01055'], 'Biosynthesis-of-other-secondary-metabolites': ['map00940', 'map00945', 'map00941', 'map00944', 'map00942', 'map00943', 'map00901', 'map00403', 'map00950', 'map00960', 'map01058', 'map00232', 'map00965', 'map00966', 'map00402', 'map00311', 'map00332', 'map00261', 'map00331', 'map00521', 'map00524', 'map00525', 'map00401', 'map00404', 'map00405', 'map00333', 'map00254', 'map00999', 'map00998', 'map00997'], 'Xenobiotics-biodegradation-and-metabolism': ['map00362', 'map00627', 'map00364', 'map00625', 'map00361', 'map00623', 'map00622', 'map00633', 'map00642', 'map00643', 'map00791', 'map00930', 'map00363', 'map00621', 'map00626', 'map00624', 'map00365', 'map00984', 'map00980', 'map00982', 'map00983'], 'Chemical-structure-transformation-maps': ['map01010', 'map01060', 'map01061', 'map01062', 'map01063', 'map01064', 'map01065', 'map01066', 'map01070'], 'Transcription': ['map03020', 'map03022', 'map03040'], 'Translation': ['map03010', 'map00970', 'map03013', 'map03015', 'map03008'], 'Folding,-sorting-and-degradation': ['map03060', 'map04141', 'map04130', 'map04120', 'map04122', 'map03050', 'map03018'], 'Replication-and-repair': ['map03030', 'map03410', 'map03420', 'map03430', 'map03440', 'map03450', 'map03460'], 'Membrane-transport': ['map02010', 'map02060', 'map03070'], 'Signal-transduction': ['map02020', 'map04014', 'map04015', 'map04010', 'map04013', 'map04016', 'map04011', 'map04012', 'map04310', 'map04330', 'map04340', 'map04341', 'map04350', 'map04390', 'map04391', 'map04392', 'map04370', 'map04371', 'map04630', 'map04064', 'map04668', 'map04066', 'map04068', 'map04020', 'map04070', 'map04072', 'map04071', 'map04024', 'map04022', 'map04151', 'map04152', 'map04150', 'map04075'], 'Signaling-molecules-and-interaction': ['map04080', 'map04060', 'map04061', 'map04512', 'map04514'], 'Transport-and-catabolism': ['map04144', 'map04145', 'map04142', 'map04146', 'map04140', 'map04138', 'map04136', 'map04137', 'map04139'], 'Cell-growth-and-death': ['map04110', 'map04111', 'map04112', 'map04113', 'map04114', 'map04210', 'map04214', 'map04215', 'map04216', 'map04217', 'map04115', 'map04218'], 'Cellular-community---eukaryotes': ['map04510', 'map04520', 'map04530', ...

# %%
pickle.dump(map_name, open( "mapname.pkl", "wb" ) )
pickle.dump(map_id, open( "mapid.pkl", "wb" ) )
pickle.dump(label, open( "label.pkl", "wb" ) )
